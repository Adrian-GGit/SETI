plt.plot(epochs, fod_val_acc, label="original data val", linestyle="dashed", color="red")
plt.plot(epochs, wd_val_acc, label="weighted data val", linestyle="dashed", color="blue")
plt.plot(epochs, hd_val_acc, label="hybrid data val", linestyle="dashed", color="green")
plt.plot(epochs, wd_val_acc_ef5, label="weighted data val efn5", linestyle="dashed", color="black")
plt.xlabel("Epoch")
plt.ylabel("Accuracy %")
plt.legend(bbox_to_anchor=(1.05, 0.6))
plt.show()

# %%
plt.plot(epochs, fod_train_recall, label="original data train", color="red")
plt.plot(epochs, wd_train_recall, label="weighted data train", color="blue")
plt.plot(epochs, hd_train_recall, label="hybrid data train", color="green")
plt.plot(epochs, wd_train_recall_ef5, label="weighted data train efn5", color="black")
plt.plot(epochs, fod_val_recall, label="original data val", linestyle="dashed", color="red")
plt.plot(epochs, wd_val_recall, label="weighted data val", linestyle="dashed", color="blue")
plt.plot(epochs, hd_val_recall, label="hybrid data val", linestyle="dashed", color="green")
plt.plot(epochs, wd_val_recall_ef5, label="weighted data val efn5", linestyle="dashed", color="black")
plt.xlabel("Epoch")
plt.ylabel("Recall %")
plt.legend(bbox_to_anchor=(1.05, 0.6))
plt.show()

# %%
plt.plot(epochs, fod_train_precision, label="original data train", color="red")
plt.plot(epochs, wd_train_precision, label="weighted data train", color="blue")
plt.plot(epochs, hd_train_precision, label="hybrid data train", color="green")
plt.plot(epochs, wd_train_precision_ef5, label="weighted data train efn5", color="black")
plt.plot(epochs, fod_val_precision, label="original data val", linestyle="dashed", color="red")
plt.plot(epochs, wd_val_precision, label="weighted data val", linestyle="dashed", color="blue")
plt.plot(epochs, hd_val_precision, label="hybrid data val", linestyle="dashed", color="green")
plt.plot(epochs, wd_val_precision_ef5, label="weighted data val efn5", linestyle="dashed", color="black")
plt.xlabel("Epoch")
plt.ylabel("Precision %")
plt.legend(bbox_to_anchor=(1.05, 0.6))
plt.show()

# %%
plt.plot(epochs, fod_train_loss, label="original data train", color="red")
plt.plot(epochs, wd_train_loss, label="weighted data train", color="blue")
plt.plot(epochs, hd_train_loss, label="hybrid data train", color="green")
plt.plot(epochs, wd_train_loss_ef5, label="weighted data train efn5", color="black")
plt.plot(epochs, fod_val_loss, label="original data val", linestyle="dashed", color="red")
plt.plot(epochs, wd_val_loss, label="weighted data val", linestyle="dashed", color="blue")
plt.plot(epochs, hd_val_loss, label="hybrid data val", linestyle="dashed", color="green")
plt.plot(epochs, wd_val_loss_ef5, label="weighted data val efn5", linestyle="dashed", color="black")
plt.xlabel("Epoch")
plt.ylabel("Avg loss")
plt.legend(bbox_to_anchor=(1.05, 0.6))
plt.show()

# %%
plt.plot(epochs, fod_val_roc_auc, label="original data val", linestyle="dashed", color="red")
plt.plot(epochs, wd_val_roc_auc, label="weighted data val", linestyle="dashed", color="blue")
plt.plot(epochs, hd_val_roc_auc, label="hybrid data val", linestyle="dashed", color="green")
plt.plot(epochs, wd_val_roc_auc_ef5, label="weighted data val efn5", linestyle="dashed", color="black")
plt.xlabel("Epoch")
plt.ylabel("Roc Auc")
plt.legend(bbox_to_anchor=(1.05, 0.6))
plt.show()
